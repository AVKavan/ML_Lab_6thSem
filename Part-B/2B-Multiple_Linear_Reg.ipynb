# %%
import pandas as pd
df = pd.read_csv('Advertising.csv')
print(df.head())
print(df.shape)
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9
# (200, 5)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x_train,x_test,y_train,y_test = train_test_split(df.drop(['Sales'],axis = 1),df['Sales'],test_size = 0.3)
lr = LinearRegression()
lr.fit(x_train,y_train)

print("The equation is is y = {:.5} + {:.5}*Tv + {:.5}*Radio + {:.5}*Newspaper".format(lr.intercept_,lr.coef_[0],lr.coef_[1],lr.coef_[2]))

y_pred = lr.predict(x_test)
# Out:
# The equation is is y = 3.6594 + -0.0030627*Tv + 0.044395*Radio + 0.19533*Newspaper

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error

rmse=np.sqrt(mean_squared_error(y_test,y_pred))
#Finiding Mean Absolute Error
mae = mean_absolute_error(y_test,y_pred)
#Finding Mean Squared Error
mse = mean_squared_error(y_test,y_pred)

print("RMSE = ",rmse)
print("MAE = ",mae)
print("MSE = ",mse)
# Out:
# RMSE =  2.082613218816231
# MAE =  1.4150809047544095
# MSE =  4.337277819188103

# %%
import seaborn as sns
sns.pairplot(df,x_vars=['TV','Radio','Newspaper'],y_vars='Sales',kind = 'reg',height=5,aspect=1)
