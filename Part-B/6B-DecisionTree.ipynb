# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('iris.csv')
df
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.drop(['Class'],axis=1),df['Class'],test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(criterion='entropy')
model = dtc.fit(x_train,y_train)
prediction = model.predict(x_test)
print("prediction : ",prediction[:5])
# Out:
# prediction :  ['Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor']

# %%
from sklearn.metrics import confusion_matrix, matthews_corrcoef, classification_report, accuracy_score
import seaborn as sns
cm = confusion_matrix(y_test,prediction)
print("Accuracy = ",accuracy_score(y_test,prediction))
print("matthews_corrcoef = ",matthews_corrcoef(y_test,prediction))
print(classification_report(y_test,prediction))
sns.heatmap(cm,annot = True)
# Out:
# Accuracy =  0.9333333333333333
# matthews_corrcoef =  0.8976109215017065
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       0.89      0.89      0.89         9
#  Iris-virginica       0.88      0.88      0.88         8
#
#        accuracy                           0.93        30
#       macro avg       0.92      0.92      0.92        30
#    weighted avg       0.93      0.93      0.93        30
# <AxesSubplot:>

# %%
from sklearn import tree
tree.plot_tree(dtc)
# Out:
# [Text(0.4, 0.9, 'X[2] <= 2.35\nentropy = 1.583\nsamples = 120\nvalue = [37, 41, 42]'),
#  Text(0.3, 0.7, 'entropy = 0.0\nsamples = 37\nvalue = [37, 0, 0]'),
#  Text(0.5, 0.7, 'X[3] <= 1.65\nentropy = 1.0\nsamples = 83\nvalue = [0, 41, 42]'),
#  Text(0.2, 0.5, 'X[2] <= 4.95\nentropy = 0.276\nsamples = 42\nvalue = [0, 40, 2]'),
#  Text(0.1, 0.3, 'entropy = 0.0\nsamples = 39\nvalue = [0, 39, 0]'),
#  Text(0.3, 0.3, 'X[3] <= 1.55\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.2, 0.1, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.4, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8, 0.5, 'X[2] <= 4.85\nentropy = 0.165\nsamples = 41\nvalue = [0, 1, 40]'),
#  Text(0.7, 0.3, 'X[1] <= 3.0\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6, 0.1, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9, 0.3, 'entropy = 0.0\nsamples = 38\nvalue = [0, 0, 38]')]

# %%
from sklearn.tree import DecisionTreeClassifier
dtc_gini = DecisionTreeClassifier(criterion='gini')
model = dtc_gini.fit(x_train,y_train)
prediction_gini = model.predict(x_test)
print("prediction : ",prediction_gini[:5])
# Out:
# prediction :  ['Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor']

# %%
from sklearn.metrics import confusion_matrix, matthews_corrcoef, classification_report, accuracy_score
import seaborn as sns
cm = confusion_matrix(y_test,prediction_gini)
print("Accuracy = ",accuracy_score(y_test,prediction_gini))
print("matthews_corrcoef = ",matthews_corrcoef(y_test,prediction_gini))
print(classification_report(y_test,prediction_gini))
sns.heatmap(cm,annot = True)
# Out:
# Accuracy =  0.9333333333333333
# matthews_corrcoef =  0.8976109215017065
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       0.89      0.89      0.89         9
#  Iris-virginica       0.88      0.88      0.88         8
#
#        accuracy                           0.93        30
#       macro avg       0.92      0.92      0.92        30
#    weighted avg       0.93      0.93      0.93        30
# <AxesSubplot:>

# %%
tree.plot_tree(dtc_gini)
# Out:
# [Text(0.4, 0.9, 'X[3] <= 0.8\ngini = 0.666\nsamples = 120\nvalue = [37, 41, 42]'),
#  Text(0.3, 0.7, 'gini = 0.0\nsamples = 37\nvalue = [37, 0, 0]'),
#  Text(0.5, 0.7, 'X[3] <= 1.65\ngini = 0.5\nsamples = 83\nvalue = [0, 41, 42]'),
#  Text(0.2, 0.5, 'X[2] <= 4.95\ngini = 0.091\nsamples = 42\nvalue = [0, 40, 2]'),
#  Text(0.1, 0.3, 'gini = 0.0\nsamples = 39\nvalue = [0, 39, 0]'),
#  Text(0.3, 0.3, 'X[3] <= 1.55\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.2, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.4, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8, 0.5, 'X[2] <= 4.85\ngini = 0.048\nsamples = 41\nvalue = [0, 1, 40]'),
#  Text(0.7, 0.3, 'X[1] <= 3.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9, 0.3, 'gini = 0.0\nsamples = 38\nvalue = [0, 0, 38]')]
